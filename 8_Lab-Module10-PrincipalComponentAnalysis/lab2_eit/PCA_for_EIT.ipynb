# %% [markdown]
# # PCA for Source Separation of Ventilation and Cardiovascular Activity in Electrical Impedance Tomography (EIT)
#
# ## Introduction
# In this exercise we use PCA for processing image sequences of thoracic electrical impedance tomography (EIT) signals. EIT is a non-invasive, radiation-free imaging modality which uses small alternating currents to measure bioimpedance of the thorax [1]. These measurements are then converted into image sequences of thoracic impedance changes representing ventilation (i.e., air exchange in the lungs) and cardiovascular activity (e.g., heart movement or blood volume changes in heart and lungs).
#
# In order to analyze these data it is important to properly separate ventilation and cardiovascular activity. Besides common techniques such as frequency filtering or ECG-triggered averaging, PCA can be used for separating these two sources of signals.
# The present example uses the method proposed by Deibele et al. [2] for which the block diagram is shown below:
#
# <img src="FlowChart_Deibele.png">
#
#
# ## References
#
# [1] I. Frerichs et al., “Chest electrical impedance tomography examination, data analysis, terminology, clinical use and recommendations: consensus statement of the TRanslational EIT developmeNt stuDy group,” Thorax, vol. 72, no. 1, pp. 83–93, Jan. 2017, doi: [10.1136/thoraxjnl-2016-208357](https://dx.doi.org/10.1136/thoraxjnl-2016-208357).
#
# [2] J. M. Deibele, H. Luepschen, and S. Leonhardt, “Dynamic separation of pulmonary and cardiac changes in electrical impedance tomography,” Physiological Measurement, vol. 29, no. 6, pp. S1–S14, Jun. 2008, doi: [10.1088/0967-3334/29/6/S01](https://dx.doi.org/10.1088/0967-3334/29/6/S01).

# %%
import numpy as np
from scipy.io import loadmat
from scipy.signal import filtfilt, butter
from scipy.linalg import eigh

import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly.subplots import make_subplots
init_notebook_mode(connected=True)  # initiate notebook for offline plot

from ecgdetectors import Detectors
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>

# %%
# load data
data = loadmat('EIT_Data.mat')
t = data['tEit'].flatten()[data['IdxRange'].flatten().astype(bool)]
fs = 1/np.median(np.diff(t))
imgs_eit = data['Imgs']
b, a = butter(4, np.asarray([0.1, 12]), fs=fs, btype='bandpass')
imgs_eit = filtfilt(b, a, imgs_eit, axis=-1)
imgs_eit *= 1E3  # adapt scaling for plotting

# ECG data to be used for bonus question
ecg = {'time': data['Ecg'][0][0][2], 'value': data['Ecg'][0][0][1], 'fs': data['Ecg'][0][0][3]}
ecg_range = (ecg['time'] > t[0]) & (ecg['time'] < t[-1])
ecg['time'] = ecg['time'][ecg_range]
ecg['value'] = ecg['value'][ecg_range]

# force all timings to start at zero
t -= t[0]
ecg['time'] -= ecg['time'][0]

# %%
# plot input data
fig = make_subplots(rows=1, cols=2, column_widths=[1, 2])
fig.update_layout(width=950, height=400)

fig.add_trace(go.Heatmap(z=np.std(imgs_eit, axis=-1), zmin=0, 
                         showscale=False, colorscale='magma'), row=1, col=1)
fig.update_yaxes(title='Right', showticklabels=False, autorange="reversed", row=1, col=1)
fig.update_xaxes(title='Dorsal', showticklabels=False, row=1, col=1)
fig.update_layout(title='Overall EIT Activity')

fig.add_trace(go.Scatter(x=t, y=np.nansum(imgs_eit, axis=(0, 1)), 
                         name='Overall Sum Signal', line_color='black'), row=1, col=2)
fig.update_xaxes(title='Time (s)', row=1, col=2)
fig.update_yaxes(title='Impedance Change \\Delta Z (A.U.)', row=1, col=2)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="d5c935ab-6445-4b32-8985-d258b238cb6f" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d5c935ab-6445-4b32-8985-d258b238cb6f")) {                    Plotly.newPlot(                        "d5c935ab-6445-4b32-8985-d258b238cb6f",                        [{"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"showscale":false,"z":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fxV9AKgdBVI\u002fMxLpCssITT\u002fAAEf51u9TP2LURf+L+Vk\u002fm5QPj61kUz+HNKDPc7FDPwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002f6J7Zd1Hz00\u002fsjF1owmLWD+NmcHx88hZPx+SbPRjZVQ\u002fc8VZtiX+Wz9V+KBhduphPz7Fy6EtYFw\u002fq5kSzbEqUz+NGpRmiDlVP6j8QlxiP1Y\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002f8ov\u002f6YPyUD+i01uDk0pVP\u002fl9EhM36WI\u002f7kUMffZpYz\u002fZI5RgU0hdP8hLth4UP2E\u002fPb58o1vGZT8gb65XOftiPzeDiTpeMl8\u002fRxVv8EN3YD\u002ffujXAWfhfP5BX02I3YlQ\u002fdOvoMLY\u002fQT8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fmscndmOYXj8k1UW2VepeP9eQlj6z0FM\u002f8Av63x0aZT\u002fcm4dCJIJwPy1ns9y8YnA\u002fDuKKkc5tZz\u002fLR1R+S1hkP0GxPpKTS2g\u002fhsSEf6UFZz9kNytkYLhkPzWqmoqG62Q\u002fz6+3j2RuYj+Px1e+PbZWP3yQ\u002fMCBh1A\u002fYAtbqL3WUD8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P93KADsBddePweI2vPgn2U\u002f4iYOnpf8XT+aP2lp7\u002f9iP6dY6JyvYnU\u002foyUvjyS5fD9O5bD4Do57P6HpNbdFVHQ\u002fawmcEuhCbD\u002fEbeae6FlrPx7i7L0a6Wo\u002fnVqnKlziaD9dGqFaYGRnP0bffRdiZWI\u002fIfikKh0wWD\u002f5sBxBEqRaP1n0HNBB81k\u002fftO0tBILUD8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAA ...

# %%
def compute_principal_components(X):
    # perform PCA and compute principal components (pc) and eigenvalues of X
    A = np.dot(X.transpose(), X)  # covariance matrix
    [eigenvalues, eigenvectors] = eigh(A)
    pc = np.dot(X, eigenvectors)
    return pc, eigenvalues

def estimate_cardiac_frequency(s, fs):
    sign_cardiac = np.sign(s)
    # find where zero crossings occured
    index = np.where(np.diff(sign_cardiac) == 2)[0]
    # interpolate to a sub-sample resolution
    pos = index + s[index + 1] / (s[index + 1] - s[index])
    # interpolate RR interval values
    rr = np.diff(pos) / fs
    return 1/np.median(rr)

def lms(A, B):
    if B.ndim == 1:
        B = np.asmatrix(B).transpose()
    tmp = np.linalg.solve(np.dot(B.transpose(), B), B.transpose())
    return np.dot(np.dot(B, tmp), A)

# separate ventilation and cardiovascular activity using PCA
# according to the algorithm by Deibele et al., PhysMeas, 2008
# https://dx.doi.org/10.1088/0967-3334/29/6/S01
imgs_tmp = np.reshape(imgs_eit, [-1, imgs_eit.shape[-1]])
are_valid_pixels = np.all(~np.isnan(imgs_tmp), 1)
X = imgs_tmp[are_valid_pixels, :].transpose()

# first approximation (see block diagram)
X = X - np.repeat(np.reshape(np.mean(X, 0), [1, -1]), X.shape[0], 0)
PC1, lambda1 = compute_principal_components(X)
Bv = PC1[:, -1]
Xv_ = lms(X, Bv)
Xc_ = X - Xv_

# second approximation (see block diagram)
Xc_ = Xc_ - np.repeat(np.reshape(np.mean(Xc_, 0), [1, -1]), Xc_.shape[0], 0)
b, a = butter(6, np.asarray([0.92, 4.6]), fs=fs, btype='bandpass')
Xc_bp = filtfilt(b, a, Xc_, axis=0)
PC2, lambda2 = compute_principal_components(Xc_bp)
Bc_ = PC2[:, -2:]
fc = estimate_cardiac_frequency(Bc_[:, 0], fs)

# create cardiac template functions
Bc = np.hstack((Bc_, np.roll(Bc_, int(fs/fc/3), 0),
                np.roll(Bc_, -int(fs/fc/3), 0)))
Xc1 = lms(Xc_, Bc)
Xc2 = lms(Xv_, Bc)
Xc = (Xc1 + Xc2).transpose()
Xv = (Xv_ - Xc2).transpose()

# cardiovascular activity
imgs_card = np.full(imgs_tmp.shape, np.nan)
imgs_card[are_valid_pixels, :] = Xc
imgs_card = imgs_card.reshape(imgs_eit.shape)
# ventilation activity
imgs_vent = np.full(imgs_tmp.shape, np.nan)
imgs_vent[are_valid_pixels, :] = Xv
imgs_vent = imgs_vent.reshape(imgs_eit.shape)

# %%
# plot ventilation acticity
fig = make_subplots(rows=1, cols=2, column_widths=[1, 2])
fig.update_layout(width=950, height=400)

fig.add_trace(go.Heatmap(z=np.std(imgs_vent, axis=-1), zmin=0, 
                         showscale=False, colorscale='magma'), row=1, col=1)
fig.update_yaxes(title='Right', showticklabels=False, autorange="reversed", row=1, col=1)
fig.update_xaxes(title='Dorsal', showticklabels=False, row=1, col=1)
fig.update_layout(title='Ventilation Activity')

fig.add_trace(go.Scatter(x=t, y=np.nanmean(imgs_vent, axis=(0, 1)), 
                         name='Mean Signal', line_color='black'), row=1, col=2)
fig.update_xaxes(title='Time (s)', row=1, col=2)
fig.update_yaxes(title='Impedance Change \\Delta Z (A.U.)', row=1, col=2)

# add example signals in ??? regions
regions = {'Region RL': ([10, 14], 'magenta'), 'Region LL': ([22, 14], 'orange')}
for reg, tmp in regions.items():
    fig.add_scatter(x=[tmp[0][0]], y=[tmp[0][1]], mode='markers', marker_symbol='square-open', 
                    marker_size=10, legendgroup=reg, marker_color=tmp[1], name=reg, row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=imgs_vent[tmp[0][1], tmp[0][0], :], legendgroup=reg, 
                             showlegend=False, name=reg, line_color=tmp[1]), row=1, col=2) 
    
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="27519acf-d412-4eed-8e27-8e03fc01f95e" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("27519acf-d412-4eed-8e27-8e03fc01f95e")) {                    Plotly.newPlot(                        "27519acf-d412-4eed-8e27-8e03fc01f95e",                        [{"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"showscale":false,"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f6KJVahe30E\u002fceaeICCbQT9EWblglXISPwcYH4anzS0\u002fX5jWAYs4Jj\u002fuvuLlnt8lPwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f96YNh4cvDE\u002fcx+y23r\u002fOD\u002fQn1rYJgtDP1l+gkqRpTg\u002fcMLVVErjIz+wgQdZZoxCP4xYCGbn5EE\u002fi9YHx8mpRT\u002f\u002fovTSO0lPP4s3S9Do+lA\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002ffC40nPxfRj\u002fGX5tqvT05P\u002f\u002fxKpaezVQ\u002fxdm7jXvkVT+AOpAlRoVIP1TkFv5RkA4\u002ft2WgC9I6RT9AckD45m5KPwGi9fTTMVM\u002fEzjjV0hcWT\u002fe+JlpgGlZP\u002fensxMQxUw\u002f1B3Q48N3ID8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002f1kSSE4gaXD9xZ\u002fRwOzlZPwDzT4pVpNs+XJR2V5aGYD\u002fD5GQmDSZrP1Fn+uHljGo\u002f7tyapU1+YT9Lja5mfkBIP37vZBFK0iU\u002fRH7ixFnBRD\u002fRsKyEhDlVP5p69oCvF14\u002fJ69yEYlwXD+qxTjej81KP4o2WhUEAC4\u002fGvjp3+FPQD8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H97KRN1NxtcP6K7oQ7p72M\u002fq9YEhuHjVD+ynXPPPz9cP54aleXY5HM\u002f3JhtzsPsej+JHteoxqR5P14eqxPCl3I\u002fRpGksOHzYz+4cV7G\u002fjhRP8Ryz9\u002fiuyk\u002f+v5ELRB3SD81WLni7uhYP+NdWmx1+FU\u002f9kHeBe78Lz\u002fmts3tuD1GP5nvuk+XF0s\u002fLuaTQ6aQOT8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f8augNrLTlQ\u002fdrc1X4rgZD8o41pN8IlgP3fH9BYWOkI\u002fMhuiGdG5cz\u002fRc+Nc57eCPy4Nyir4yoY\u002fQu\u002fztifxhD96E6JR5mV\u00 ...

# %%
# plot cardiovascular acticity
fig = make_subplots(rows=1, cols=2, column_widths=[1, 2])
fig.update_layout(width=950, height=400)

fig.add_trace(go.Heatmap(z=np.std(imgs_card, axis=-1), zmin=0, 
                         showscale=False, colorscale='magma'), row=1, col=1)
fig.update_yaxes(title='Right', showticklabels=False, autorange="reversed", row=1, col=1)
fig.update_xaxes(title='Dorsal', showticklabels=False, row=1, col=1)
fig.update_layout(title='Cardiovascular Activity')

fig.add_trace(go.Scatter(x=t, y=np.nanmean(imgs_card, axis=(0, 1)), 
                         name='Mean Signal', line_color='black'), row=1, col=2)
fig.update_xaxes(title='Time (s)', row=1, col=2)
fig.update_yaxes(title='Impedance Change \\Delta Z (A.U.)', row=1, col=2)

# add three example signals in ??? regions
regions = {'Region A': ([18, 9], 'green'), 'Region B': ([10, 15], 'blue'), 'Region C': ([23, 15], 'red')}
for reg, tmp in regions.items():
    fig.add_scatter(x=[tmp[0][0]], y=[tmp[0][1]], mode='markers', marker_symbol='square-open', 
                    marker_size=10, legendgroup=reg, marker_color=tmp[1], name=reg, row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=imgs_card[tmp[0][1], tmp[0][0], :], legendgroup=reg, 
                             showlegend=False, name=reg, line_color=tmp[1]), row=1, col=2)    
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="2af1d0e2-6248-4715-9f57-1f0dda4de27f" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2af1d0e2-6248-4715-9f57-1f0dda4de27f")) {                    Plotly.newPlot(                        "2af1d0e2-6248-4715-9f57-1f0dda4de27f",                        [{"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"showscale":false,"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f3XcHfx5xDg\u002fFy2TnrRTLD+uqtKgnLU3P30JlmqtxUE\u002f4KTst34RPz+5APN\u002fxGI1PwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f6Fbsn8zXDg\u002fb+0rzIngQz81a6uasGhDP1qOJxmuKzg\u002fqWyd2cJ\u002fQD8Mih9ZNSZJP819P74Rtkg\u002fnnTqM2+KQz\u002fnZ0c\u002fElI\u002fP+WodfVAKjo\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAIsC2Bs7Mj+d8zRNwyFDP6rZsokSMUw\u002fClJ1i4zJSj+jcIkU1OlAP7JCAV5yZEY\u002f24Ha5LrJUT9h8PN04XNTP9aeeVN1ilA\u002fktr\u002fLmtwSD8vGW9BYn9CPwRXiTO1Nzs\u002fZg7Uw75GMj8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002faG7V8SFsIj\u002f0J6dlrGIxP5R18mbLmj4\u002fsSIOouKcSj+kWy9fTupRP1\u002fcSnc4Y1A\u002f3yHO8l2\u002fQz9pP2FwCcVNP3GIjIN4flg\u002faaPsmvUyXD9Opp+Y\u002fzlZPxB0KsNCjlI\u002fFs2DjgoQSD+hvp9UJC0+PxzXiBmljjk\u002ff7XlAXbqNT8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8bC9SQpVkeP4q4JhqqxR4\u002fvfjaDa5yNj8hkd1CnDJGP8085VczFlE\u002fy2jCfCBjVD+vR6VEwyhRPyXYLoyCqUM\u002f1qXBKbFTUj8bZQ8G67teP1a8uaw7XGI\u002fffybZYlnYT\u002fvefd8quNaP8AWRttVUVA\u002fG1uZXQGXPT+W0LElHDM+P0ePUfQMiUE\u002fM\u002f6MmzVlOT8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f\u002fL1BW9o1DI\u002fP99G5XgwMz82hTyDM4oxP4JP4yQFkkE\u002fmrf55f+0Tj8lk\u002ftbI\u002fNUP7eJ0PIe8lU\u002fnD4D1GQPUD9NQgWXjiBCPzHpj3\u002fN ...

# %% [markdown]
# # Exercise Questions
# Please provide your answers directly below each question.
#
# ---
#
# ## Question 1
# Determine the frequency of the ventilation activity (i.e., the respiratory rate), both expressed in `Hz` and `respirations/min`.

# %%
vent_signal = np.nanmean(imgs_vent, axis=(0,1))
vent_freq = estimate_cardiac_frequency(vent_signal, fs)
print("Ventilation frequency (Hz):", vent_freq)
print("Ventilation rate (resp/min):", vent_freq*60)
# Out:
# Ventilation frequency (Hz): 0.3233647300259453
# Ventilation rate (resp/min): 19.401883801556718

# %% [markdown]
# **Answer:** The estimated frequency of the ventilation activity is 0.323 Hz, which corresponds to approximately 19.4 respirations per minute.

# %% [markdown]
# ## Question 2
# Determine the frequency of the cardiovascular activity, both expressed in `Hz` and `beats/min`.

# %%
card_signal = np.nanmean(imgs_card, axis=(0,1))
card_freq = estimate_cardiac_frequency(card_signal, fs)
print("Cardiovascular frequency (Hz):", card_freq)
print("Heart rate (beats/min):", card_freq*60)
# Out:
# Cardiovascular frequency (Hz): 0.9750076200804776
# Heart rate (beats/min): 58.500457204828656

# %% [markdown]
# **Answer:** The estimated frequency of the cardiovascular activity is 0.975Hz, which corresponds to approximately 58.5 BPM.

# %% [markdown]
# ## Question 3
# Determine the follwing three values:
#
# - i) the maximal amplitude of ventilation activity;
# - ii) the maximal amplitude of cardiovascular activity; and
# - iii) the ratio between i) and ii), i.e., ventilation vs cardiovascular activity.

# %%
vent_amp = np.nanmax(np.abs(imgs_vent))
card_amp = np.nanmax(np.abs(imgs_card))
ratio = vent_amp / card_amp
print("Ventilation max amplitude:", vent_amp)
print("Cardiovascular max amplitude:", card_amp)
print("Ventilation/Cardiovascular ratio:", ratio)
# Out:
# Ventilation max amplitude: 0.053047195588818555
# Cardiovascular max amplitude: 0.006880552661113803
# Ventilation/Cardiovascular ratio: 7.709728883934075

# %% [markdown]
# **Question:** The maximal amplitude of ventilation activity is 0.0530, while the maximum amplitude of cardiovascular activity is 0.00688. This yields a ventilation to cardiac ratio of 7.71.

# %% [markdown]
# ## Question 4
# Determine the eigenvalues of the first three principal components resulting from the first PCA (see variable `PC1`).

# %%
print("First 3 eigenvalues:", lambda1[-3:])
# Out:
# First 3 eigenvalues: [  0.80315244   2.11148888 107.58688656]

# %% [markdown]
# **Answer:** The three largest eigenvalues of the PCA decomposition are 0.0803, 2.11, and 107.6. Since eigh() returns eigenvalues in ascending order, the largest values are the last ones in lambda1 (hence the lambda1[-3].)

# %% [markdown]
# ## Question 5
# Similar to Question 4, determine the two most dominant frequencies for the first three principal components. <i>Note that this would lead to a total of 6 values, 2 frequencies for each of the 3 PCA components. However, for some components only one dominant frequency might be present.</i><br>
# For all 3 PCA components, which one is rather related to ventilation or cardiovascular activity?

# %%
from scipy.signal import find_peaks

pc_components = PC1[:, -3:]
n_peaks=2

for i in range(3):
    n = len(pc_components[:, i])
    fft_vals = np.fft.rfft(pc_components[:, i])
    fft_freq = np.fft.rfftfreq(n, 1/fs)
    fft_mag = np.abs(fft_vals)
    
    peaks, _ = find_peaks(fft_mag, height=np.max(fft_mag)*0.05)
    peak_freqs = fft_freq[peaks]
    peak_mags = fft_mag[peaks]
    
    sorted_indices = np.argsort(peak_mags)[::-1]
    dominant_freqs = peak_freqs[sorted_indices][:n_peaks]

    print(f"PC{i+1} dominant frequencies (Hz):", np.sort(dominant_freqs))
# Out:
# PC1 dominant frequencies (Hz): [0.31954524 0.95863573]
# PC2 dominant frequencies (Hz): [0.31954524 0.95863573]
# PC3 dominant frequencies (Hz): [0.31954524 0.39943156]

# %% [markdown]
# **Answer:** In both PC1 and PC2, the strongest peaks occur at 0.32Hz, which corresponds to ventilation, and 0.96Hz, which corresponds to cardiac activity. As for PC3, its strongest peaks occur at 0.32Hz and 0.40Hz, which correspond respectively to ventilation activity and a weaker secondary harmonic.

# %% [markdown]
# ## Question 6
# The three example signals (Regions A to C: **green, blue, red**) of cardiovascular activity show the impedance change over time.
# Can you guess the underlying anatomical structure for each of the three example signals (Regions A to C: **green, blue, red**).

# %% [markdown]
# **Answer:** Region A (green) has the largest amplitude and sharpest pulsations and is located somewhat centrally, which indicates that it likely corresponds to the heart area, where the pulse is the strongest.
#
# Region B (blue) has the smallest and most attenuated pulse waveform and is located in a more peripheral area in the image. This could correspond to areas of the lungs, where the heartbeat signal becomes weaker.
#
# Region C (red) shows intermediate amplitude that is slightly larger than the blue one, which suggests that it comes from a border region near the heart (therefore in between the heart and the lungs).

# %% [markdown]
# ## Question 7 - *Bonus Question* (not graded)
# Can you detect the QRS peaks (e.g., using [`qrs = Detectors(fs).engzee_detector(ecg)`](https://github.com/berndporr/py-ecg-detectors/blob/7a1ca569190a4c17885089c97480efd114c64120/ecgdetectors.py#L277)) on the ECG signal (see variable `ecg`) and plot them together with the cardiovascular EIT activity?

# %%
# Question 7: detect QRS peaks on the ECG and plot together with cardiovascular EIT activity
# Use the Detectors class imported earlier
try:
    detectors = Detectors(int(ecg['fs']))
    qrs_idx = detectors.engzee_detector(ecg['value'])
except Exception as e:
    print('QRS detector error:', e)
    qrs_idx = []
qrs_idx = np.array(qrs_idx)
print(f'Detected {len(qrs_idx)} QRS peaks (ECG).')
# Prepare times of detected QRS peaks (ecg['time'] is already aligned to t)
if len(qrs_idx) > 0:
    qrs_times = ecg['time'][qrs_idx]  # seconds
    # Map QRS times onto EIT timeline and extract y-values from mean cardiac EIT signal
    card_mean = np.nanmean(imgs_card, axis=(0,1))
    # Interpolate EIT mean signal at QRS times for marker placement
    qrs_y = np.interp(qrs_times, t, card_mean)
    # Plot EIT mean and QRS markers
    fig = make_subplots(rows=1, cols=1)
    fig.add_trace(go.Scatter(x=t, y=card_mean, name='Cardiovascular EIT mean', line_color='black'))
    fig.add_trace(go.Scatter(x=qrs_times, y=qrs_y, mode='markers', 
                         marker=dict(color='red', size=8), name='QRS (ECG)'))
    fig.update_xaxes(title='Time (s)')
    fig.update_yaxes(title='Impedance Change or Delta Z (A.U.)')
    fig.update_layout(title='Cardiovascular EIT (mean) with ECG QRS peaks')
    fig.show()
    # Estimate HR from ECG peaks for comparison
    if len(qrs_times) > 1:
        rr = np.diff(qrs_times)
        hr_bpm = 60.0 / np.median(rr)
        print(f'Estimated HR from ECG peaks: {hr_bpm:.1f} BPM')
else:
    print('No QRS peaks to plot.')
# Out:
# Detected 46 QRS peaks (ECG).
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="9c16520f-6069-4223-a1cb-193baea189ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9c16520f-6069-4223-a1cb-193baea189ff")) {                    Plotly.newPlot(                        "9c16520f-6069-4223-a1cb-193baea189ff",                        [{"line":{"color":"black"},"name":"Cardiovascular EIT mean","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAwNVQzYWWPwCg1VDNhaY\u002fAMDOttsfsD8A8EidT4C1PwAgw4PD4Lo\u002fAKgetZsgwD8AyOuoldDCPwDouJyPgMU\u002fAAD2j8kwyD8AIMODw+DKPwA4AHf9kM0\u002fAKgetZsg0D8AOAWvmHjRPwDI66iV0NI\u002fAFSKorIo1D8A4HCcr4DVPwBwD5bM2NY\u002fAPytj+kw2D8AiEyJBonZPwAYe4Pj4No\u002fAKQZfQA53D8AaJGbvYDdPwD8v5Wa2N4\u002fAESvx1sY4D8Ain5EasTgPwDQTcF4cOE\u002fABhBPncc4j8AXhC7hcjiPwCmJzh0dOM\u002fAO72tIIg5D8ANMYxkczkPwB6la6feOU\u002fAMKIK54k5j8ACFiorNDmPwBQSyWrfOc\u002fAJY+oqko6D8A3A0fuNToPwAk3ZvGgOk\u002fAGrQGMUs6j8Asp+V09jqPwD4khLShOs\u002fAECGj9Aw7D8AhlUM39zsPwDMJIntiO0\u002fABT0Bfw07j8AWueC+uDuPwCi2v\u002f4jO8\u002fAPVmvnsc8D8AmM78gnLwPwDuETKazPA\u002fAN6deZEe8T8Aghe4kHTxPwAmkfaPyvE\u002fABcvPn8c8j8AbXJzlnbyPwBeIrt9yPI\u002fAAGK+YQe8z8ApfE3jHTzPwBIa3aLyvM\u002fAOvStJIg9D8AjzrzmXb0PwAzxjGRzPQ\u002fANYtcJgi9T8ALHGlr3z1PwAdD+2ezvU\u002fAMB2K6Yk9j8AY95prXr2PwAIaqik0PY\u002fAKvR5qsm9z8ATjkls3z3PwDxoGO60vc\u002fAJUaorko+D8AOILgwH74PwDdDR+41Pg\u002fAIB1Xb8q+T8AI92bxoD5PwDGRNrN1vk\u002fAGq+GM0s+j8ADSZX1IL6PwCxsZXL2Po\u002fAFUZ1NIu+z8A+IAS2oT7PwCb6FDh2vs\u002fAD9ij+Aw\u002fD8A4snN54b8PwCGQwzn3Pw\u002fAHbhU9Yu\u002fT8AGUmS3YT9PwC+1NDU2v0\u002fAGE8D9ww\u002fj8ABbZN24b+PwCoHYzi3P4\u002fAEuFyuky\u002fz8A7uwI8Yj\u002fPwCTeEfo3v8\\u002fOVdgRAgGCAkpWhBEAAMrQxmcwEQAAE6NCc9wRAgNUbcKAiBUAAp1gPoE0FQAB5la6feAVAgErJTaOjBUCAHAbtos4FQADuOYym+QVAAMBtK6okBkCAkaHKrU8GQIBj52mpegZAADUbCa2lBkAAB1iorNAGQIDYi0ew+wZAAKq\u002f5rMmB0CAe\u002fOFt1EHQABOOSWzfAdAgB9txLanB0CA8aljttIHQADD3QK6\u002fQdAgJQRor0oCEAAZkVBwVMIQIA4i+C8fghAAAq\u002ff8CpCECA2\u002fIexNQIQICtL77D\u002fwhAAFjIWNMsCUAAKgX40lcJQIAi3ZvGgAlAgPQQO8qrCUCA7N\\\u002fMRQIAG8WkNCRJAQO+KOY8eEkBAWCkJDzQSQEDBx9iOSRJAAKphqBBfEkAAEwB4kHQSQEAP7EkKiRJAAPiFGYyeEkDA4B\u002fpDbQSQMBJvriNyRJAgDJYiA\u002ffEkBAG\u002fJXkfQSQIAElScPChNAQO0u95AfE0AA1sjGEjUTQAA\u002fZ5aSShNAwCcBZhRgE0CAEJs1lnUTQMD5PQUUixNAgOLX1JWgE0BAy3GkF7YTQAC0C3SZyxNAAB2qQxnhE0DABUQTm\u002fYTQMDu5uIYDBRAwNeAspohFECAwBqCHDcUQECptFGeTBRAQBJTIR5iFEAA++zwn3cUQABki8AfjRRAwMwpkJ+iFECAtcNfIbgUQICeXS+jzRRAAHSu\\u002ftdzDmFkBAWIdHsvsWQEDBJRcyERdAAKq\u002f5rMmF0DAklm2NTwXQAB8\u002fIWzURdAwGSWVTVnF0CATTAlt3wXQEA2yv ...
# Estimated HR from ECG peaks: 58.0 BPM
